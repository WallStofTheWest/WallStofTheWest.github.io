# %%
# Import relevant packages
#Import Modules
import os
import numpy as np
import pandas as pd
import requests
import datetime as dt
import random

# BDay is business day
from pandas.tseries.offsets import BDay
import math
import time
import calendar
import re
from sqlalchemy import create_engine
import pymysql
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy.orm import Session

# %%
# setup pymysql and connect to local MySQL workbench
pwd="Welcome123"
pymysql.install_as_MySQLdb() 
string = f"mysql://ucbx:{pwd}@stock-data-analysis.ciuxgx1cjbsw.us-east-2.rds.amazonaws.com/stock_data"
engine = create_engine(string)
# Establish a connection to the local DB
conn = engine.connect()
# Import and establish Base for which classes will be constructed
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
class stock_yony_combined_method (Base):
    __tablename__ = 'stock_yony_combined'
    symbol = Column(String(10),primary_key=True)
    gics_sector = Column(String(100),primary_key=True)
    year_2019 = Column("2019",Float)
    year_2018 = Column("2018",Float)
    year_2017 = Column("2017",Float)
    year_2016 = Column("2016",Float)
    year_2015 = Column("2015",Float)
    year_2014 = Column("2014",Float)
    year_2013 = Column("2013",Float)
    year_2012 = Column("2012",Float)
    year_2011 = Column("2011",Float)
    year_2010 = Column("2010",Float)
    year_2009 = Column("2009",Float)
    year_2008 = Column("2008",Float)
    year_2007 = Column("2007",Float)
    year_2006 = Column("2006",Float)
    year_2005 = Column("2005",Float)
    year_2004 = Column("2004",Float)
    year_2003 = Column("2003",Float)
    year_2002 = Column("2002",Float)
    year_2001 = Column("2001",Float)
    year_2000 = Column("2000",Float)
    year_1999 = Column("1999",Float)
    year_1998 = Column("1998",Float)
    
    
class sector_yony_combined_method (Base):
    __tablename__ = 'sector_yony_combined'
    gics_sector = Column(String(100),primary_key=True)
    year_2019 = Column("2019",Float)
    year_2018 = Column("2018",Float)
    year_2017 = Column("2017",Float)
    year_2016 = Column("2016",Float)
    year_2015 = Column("2015",Float)
    year_2014 = Column("2014",Float)
    year_2013 = Column("2013",Float)
    year_2012 = Column("2012",Float)
    year_2011 = Column("2011",Float)
    year_2010 = Column("2010",Float)
    year_2009 = Column("2009",Float)
    year_2008 = Column("2008",Float)
    year_2007 = Column("2007",Float)
    year_2006 = Column("2006",Float)
    year_2005 = Column("2005",Float)
    year_2004 = Column("2004",Float)
    year_2003 = Column("2003",Float)
    year_2002 = Column("2002",Float)
    year_2001 = Column("2001",Float)
    year_2000 = Column("2000",Float)
    year_1999 = Column("1999",Float)
    year_1998 = Column("1998",Float)

# %%
# Create both the company_diversity_m_f and company_diversity_race tables within the database
Base.metadata.create_all(conn)
# confirming that tables got created in the DB
engine.table_names()
# Create a session that binds to the engine to enable insert of data
session = Session(bind=engine)

# %%
stock_yony_dividend_pulled = pd.read_sql("select * from stock_yony_dividend", con=engine)
stock_yony_return_pulled = pd.read_sql("select * from stock_yony_return", con=engine)

# %%
# stock_yony_dividend_pulled = stock_yony_return_pulled.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fdbd290a35f8> in <module>
# ----> 1 stock_yony_dividend_pulled = stock_yony_return_pulled.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
stock_yony_return_pulled
# Out:
#     symbol             gics_sector       2019       2018        2017  \
# 0        A             Health Care  15.771000   4.536470   33.318200
# 1      AAL             Industrials  10.129300 -36.165500   11.026200
# 2      AAP  Consumer Discretionary   0.810537  40.777000  -44.405500
# 3     AAPL                   FAANG   5.395140 -18.311300   30.545100
# 4     ABBV             Health Care -10.019100  -7.083760   38.109400
# 5      ABC             Health Care  11.981200 -13.543400   11.251800
# 6     ABMD             Health Care  13.263000  39.327500   49.810000
# 7      ABT             Health Care   5.007190  22.768100   35.461200
# 8      ACN  Information Technology   9.218290  -6.246330   28.372900
# 9     ADBE  Information Technology  10.353100  23.020700   55.876900
# 10     ADI  Information Technology  15.060500  -7.568780   26.890600
# 11     ADM        Consumer Staples   9.645910   7.151810  -16.389700
# 12     ADP  Information Technology   7.453510  20.041300   21.709600
# ...

# %%
stock_yoy_combined=stock_yony_dividend_pulled + stock_yony_return_pulled
stock_yoy_combined["symbol"] = stock_yony_return_pulled["symbol"]
stock_yoy_combined["gics_sector"] = stock_yony_return_pulled["gics_sector"]
stock_yoy_combined = stock_yoy_combined.reset_index(drop=True)
stock_yoy_combined
# Out:
#     symbol             gics_sector       2019       2018        2017  \
# 0        A             Health Care  15.771000   5.442729   34.217394
# 1      AAL             Industrials  10.129300 -35.401120   11.872224
# 2      AAP  Consumer Discretionary   0.810537  40.955394  -44.264968
# 3     AAPL                   FAANG   5.395140 -16.595270   32.721270
# 4     ABBV             Health Care -10.019100  -3.017460   42.289310
# 5      ABC             Health Care  11.981200 -11.850510   13.149650
# 6     ABMD             Health Care  13.263000  39.327500   49.810000
# 7      ABT             Health Care   5.007190  24.761230   38.243770
# 8      ACN  Information Technology   9.218290  -4.428740   30.536810
# 9     ADBE  Information Technology  10.353100  23.020700   55.876900
# 10     ADI  Information Technology  15.060500  -5.955150   29.411260
# 11     ADM        Consumer Staples   9.645910  10.522460  -13.555380
# 12     ADP  Information Technology   7.453510  21.911510   24.053810
# ...

# %%
sector_yony_dividend_pulled = pd.read_sql("select * from sector_yony_dividend", con=engine)
sector_yony_return_pulled = pd.read_sql("select * from sector_yony_return", con=engine)

# %%
sector_yony_dividend_pulled
# Out:
#                gics_sector  2019      2018      2017      2016      2015  \
# 0   Communication Services   0.0  1.527050  1.652760  1.769680  1.461640
# 1   Consumer Discretionary   0.0  1.467850  2.375240  4.216620  2.943300
# 2         Consumer Staples   0.0  2.083720  2.580180  3.009220  2.160720
# 3                   Energy   0.0  2.093880  1.895760  2.331690  2.147690
# 4                    FAANG   0.0  0.286005  0.362695  0.370335  0.311218
# 5               Financials   0.0  1.724730  2.312980  2.145620  1.898430
# 6              Health Care   0.0  0.840948  0.996907  1.544260  1.553080
# 7              Industrials   0.0  1.376220  1.932710  3.146280  1.879010
# 8   Information Technology   0.0  1.392170  2.289760  2.386940  2.062220
# 9                Materials   0.0  1.922330  1.829410  2.119220  1.588780
# 10             Real Estate   0.0  2.952740  3.572710  3.614380  4.324380
# 11                     S&P   0.0  1.718770  2.108150  2.537680  2.344330
# ...

# %%
sector_yony_return_pulled
# Out:
#                gics_sector      2019      2018      2017      2016       2015  \
# 0   Communication Services   7.75210  -0.95532   3.87828   2.69362  -4.485260
# 1   Consumer Discretionary   9.58005  -9.76499  13.98640   0.19791  -7.220620
# 2         Consumer Staples   6.00912  -7.20403   9.97805  -3.11335   7.960470
# 3                   Energy  12.69990 -22.14380  -7.73368  35.68240 -24.434400
# 4                    FAANG  13.37560   2.91675  36.18170   3.89422  29.351600
# 5               Financials   9.45634 -18.20950  11.53190  19.22980  -3.111850
# 6              Health Care  10.49250   1.44141  20.91910  -1.41993   5.530630
# 7              Industrials  10.46010 -11.87560  18.63720  21.12390  -6.452680
# 8   Information Technology  10.40610  -3.51198  33.39940  22.27390  -0.850893
# 9                Materials   7.48167 -17.91520  13.06760  22.86010 -13.668100
# 10             Real Estate  14.07830  -3.37557   5.81272   7.66509  -3.648120
# ...

# %%
sector_yony_combined = sector_yony_return_pulled + sector_yony_dividend_pulled

# %%
sector_yony_combined
# Out:
#                                      gics_sector      2019       2018  \
# 0   Communication ServicesCommunication Services   7.75210   0.571730
# 1   Consumer DiscretionaryConsumer Discretionary   9.58005  -8.297140
# 2               Consumer StaplesConsumer Staples   6.00912  -5.120310
# 3                                   EnergyEnergy  12.69990 -20.049920
# 4                                     FAANGFAANG  13.37560   3.202755
# 5                           FinancialsFinancials   9.45634 -16.484770
# 6                         Health CareHealth Care  10.49250   2.282358
# 7                         IndustrialsIndustrials  10.46010 -10.499380
# 8   Information TechnologyInformation Technology  10.40610  -2.119810
# 9                             MaterialsMaterials   7.48167 -15.992870
# 10                        Real EstateReal Estate  14.07830  -0.422830
# 11                                        S&PS&P   9.93639  -5.109970
# ...

# %%
sector_yony_combined["gics_sector"] = sector_yony_return_pulled["gics_sector"]
sector_yony_combined = sector_yony_combined.reset_index(drop=True)
sector_yony_combined
# Out:
#                gics_sector      2019       2018       2017       2016  \
# 0   Communication Services   7.75210   0.571730   5.531040   4.463300
# 1   Consumer Discretionary   9.58005  -8.297140  16.361640   4.414530
# 2         Consumer Staples   6.00912  -5.120310  12.558230  -0.104130
# 3                   Energy  12.69990 -20.049920  -5.837920  38.014090
# 4                    FAANG  13.37560   3.202755  36.544395   4.264555
# 5               Financials   9.45634 -16.484770  13.844880  21.375420
# 6              Health Care  10.49250   2.282358  21.916007   0.124330
# 7              Industrials  10.46010 -10.499380  20.569910  24.270180
# 8   Information Technology  10.40610  -2.119810  35.689160  24.660840
# 9                Materials   7.48167 -15.992870  14.897010  24.979320
# 10             Real Estate  14.07830  -0.422830   9.385430  11.279470
# 11                     S&P   9.93639  -5.109970  16.889650  14.685080
# ...

# %%
sector_yony_combined.to_sql(name = "sector_yony_combined",con=conn,if_exists='append', index=False)
stock_yoy_combined.to_sql(name = "stock_yoy_combined", con=conn,if_exists='append', index=False)

# %%
sector_yony_combined_pulled =  pd.read_sql("select * from sector_yony_combined", con=engine)

# %%
sector_yony_combined_pulled
# Out:
#                gics_sector      2019      2018      2017      2016      2015  \
# 0   Communication Services   7.75210   0.57173   5.53104   4.46330  -3.02362
# 1   Consumer Discretionary   9.58005  -8.29714  16.36160   4.41453  -4.27732
# 2         Consumer Staples   6.00912  -5.12031  12.55820  -0.10413  10.12120
# 3                   Energy  12.69990 -20.04990  -5.83792  38.01410 -22.28670
# 4                    FAANG  13.37560   3.20275  36.54440   4.26455  29.66280
# 5               Financials   9.45634 -16.48480  13.84490  21.37540  -1.21342
# 6              Health Care  10.49250   2.28236  21.91600   0.12433   7.08371
# 7              Industrials  10.46010 -10.49940  20.56990  24.27020  -4.57367
# 8   Information Technology  10.40610  -2.11981  35.68920  24.66080   1.21133
# 9                Materials   7.48167 -15.99290  14.89700  24.97930 -12.07930
# 10             Real Estate  14.07830  -0.42283   9.38543  11.27950   0.67626
# ...

# %%
stock_yoy_combined_pulled = pd.read_sql("select * from stock_yoy_combined", con=engine)

# %%
stock_yoy_combined_pulled
# Out:
#     symbol             gics_sector       2019       2018       2017  \
# 0        A             Health Care  15.771000   5.442730   34.21740
# 1      AAL             Industrials  10.129300 -35.401100   11.87220
# 2      AAP  Consumer Discretionary   0.810537  40.955400  -44.26500
# 3     AAPL                   FAANG   5.395140 -16.595300   32.72130
# 4     ABBV             Health Care -10.019100  -3.017460   42.28930
# 5      ABC             Health Care  11.981200 -11.850500   13.14960
# 6     ABMD             Health Care  13.263000  39.327500   49.81000
# 7      ABT             Health Care   5.007190  24.761200   38.24380
# 8      ACN  Information Technology   9.218290  -4.428740   30.53680
# 9     ADBE  Information Technology  10.353100  23.020700   55.87690
# 10     ADI  Information Technology  15.060500  -5.955150   29.41130
# 11     ADM        Consumer Staples   9.645910  10.522500  -13.55540
# 12     ADP  Information Technology   7.453510  21.911500   24.05380
# ...
